# %%
import numpy as np

# %%
import pandas as pd
import seaborn as sns

# %%
# %matplotlib inline

# %%
df1 = pd.read_csv("df1", index_col=0)
#index column is removed

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv("df2")
df2.head()
#index column present
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1["A"].hist(bins=20)
#plotting histograms

# %%
#another way of plotting
df1["A"].plot(kind="hist", bins=20)
#a list is there for type of "kinds"

# %%
df1["A"].plot.hist()

# %%
df2.plot.area(alpha=0.5)

# %%
df2.plot.bar()
#bar plot

# %%
df2.plot.bar(stacked=True)

# %%
df1.plot.line(x=df1.index, y="B", figsize=(12,3),lw=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-a6d56c6a9fe8> in <module>
# ----> 1 df1.plot.line(x=df1.index, y="B", figsize=(12,3),lw=1)
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in line(self, x, y, **kwargs)
#     916             >>> lines = df.plot.line(x='pig', y='horse')
#     917         """
# --> 918         return self(kind="line", x=x, y=y, **kwargs)
#     919
#     920     def bar(self, x=None, y=None, **kwargs):
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     810                 if is_integer(x) and not data.columns.holds_integer():
#     811                     x = data_cols[x]
# --> 812                 elif not isinstance(data[x], ABCSeries):
#     813                     raise ValueError("x must be a label or position")
#     814                 data = data.set_index(x)
#
# ...

# %%
df1.plot.scatter(x="A",y="B", cmap="coolwarm", s=df1["C"]*10)
#s= size

# %%
df2.plot.box()

# %%
df=pd.DataFrame(np.random.randn(1000,2), columns=["a","b"])
#creating own dataframe

# %%
df.head()
# Out:
#           a         b
# 0  0.792034 -0.858069
# 1 -0.446217 -0.139929
# 2 -1.625926 -0.800379
# 3 -1.106078 -1.092555
# 4 -0.983971 -0.500814

# %%
df.plot.hexbin(x="a",y="b", gridsize=20)
#hexplot
#gridsize= size of hexagons

# %%
df2["a"].plot.density()
#density=kde plot

# %%
df2.plot.density()
#kde of all columns
